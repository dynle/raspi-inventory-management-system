# %% [markdown]
# ## Model Training

# %%
num_epochs = 100

# yolov8n model
# ! yolo task=detect mode=train model=./weights/yolov8n.pt data=./dataset-new-3cls/data.yaml epochs={num_epochs} imgsz=640 device=mps patience=100

# yolov8s model
! yolo task=detect mode=train model=./weights/yolov8s.pt data=./dataset-new-3cls/data.yaml epochs={num_epochs} imgsz=640 device=mps patience=100

# yolov8m model
# ! yolo task=detect mode=train model=./weights/yolov8m.pt data=./dataset-new-3cls/data.yaml epochs={num_epochs} imgsz=640 device=mps patience=100
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.52 🚀 Python-3.8.18 torch-2.3.0 MPS (Apple M2 Pro)
# ...

# %%
# yolov8m model
! yolo task=detect mode=train model=./weights/yolov8m.pt data=./dataset-new-3cls/data.yaml epochs={num_epochs} imgsz=640 device=mps patience=100
# Out:
# New https://pypi.org/project/ultralytics/8.2.60 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.52 🚀 Python-3.8.18 torch-2.3.0 MPS (Apple M2 Pro)
# ...

# %% [markdown]
# ## Model Validation

# %%
! yolo task=detect mode=val model=./runs/exp3/weights/best.pt data=./dataset/data.yaml device=mps
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.12.3 torch-2.3.0 MPS (Apple M2 Pro)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/dynlee/Developer/IIC-detection/dataset/valid/labels.cache..
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         17         17      0.968      0.988      0.995      0.726
#          chips-consome         17          5          1      0.951      0.995      0.701
#             chips-nori         17          2      0.924          1      0.995      0.895
#           coffee-black         17          9      0.983          1      0.995      0.709
#           coffee-latte         17          1      0.963          1      0.995      0.597
# Speed: 3.9ms preprocess, 39.3ms inference, 0.0ms loss, 55.5ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
